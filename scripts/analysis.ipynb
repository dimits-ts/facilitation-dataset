# %%
# Out:
# Dataset sample:
#                                 conv_id            message_id  \
# 0  01336d04-f98a-46ec-8b1b-1eabd44f369f  -1166052103291020213
# 1  01336d04-f98a-46ec-8b1b-1eabd44f369f  -1320336919583675090
# 2  01336d04-f98a-46ec-8b1b-1eabd44f369f  -1379130414567395882
# 3  01336d04-f98a-46ec-8b1b-1eabd44f369f   -183798113354526206
# 4  01336d04-f98a-46ec-8b1b-1eabd44f369f   -185725483361844769
#
#                   reply_to              user  is_moderator  \
# 0                      NaN  MeditativeMonk81         False
# 1  -1.1660521032910203e+18  MeditativeMonk81         False
# 2  -1.3203369195836751e+18     CitySlicker05         False
# 3  -1.3791304145673958e+18     CitySlicker05         False
# 4   -1.837981133545262e+17         moderator          True
#
#                                                 text dataset  \
# 0  @CitySlicker05, I appreciate your passion for ...     vmd
# 1  @TechGuru42, I appreciate your apology and you...     vmd
# ...
